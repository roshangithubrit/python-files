# %% [markdown]
# <a href="https://colab.research.google.com/github/roshangithubrit/python-files/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks=pd.read_csv('/content/SpotifyFeatures.csv')
df_tracks.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
pd.isnull(df_tracks).sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               1
# time_signature      1
# valence             1
# dtype: int64

# %%
sorted_df = df_tracks.sort_values('popularity', ascending = True).head(10)
sorted_df
# Out:
#      genre         artist_name                                     track_name  \
# 0    Movie      Henri Salvador                    C'est beau de faire un Show
# 406  Movie              Chorus                            Jaag Uthi Hai Saari
# 405  Movie        Claire Guyot                                           Fuir
# 404  Movie              Chorus  La Sonnambula: Tutto è gioia (Act I, scene 1)
# 403  Movie            Ken Page                                J'ai Deux Amour
# 402  Movie        Debbie Davis                        Hanging Up My Stockings
# 401  Movie      Henri Salvador                                 Comme J Aimais
# 400  Movie        Randy Newman                         Little Polenta Is Born
# 399  Movie  Richard M. Sherman                            チム・チム・チェリー (竹内永和 編)
# 398  Movie              Chorus                              Udaya Gaganadalli
#
#                    track_id  popularity  acousticness  danceability  \
# ...
